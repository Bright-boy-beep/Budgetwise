# %% [markdown]
# # Notebook 01 — Data Exploration
#
# **Project:** BudgetWise — Expense Tracker & Budget Planner with ML
# **Purpose:** Load the sample transaction dataset, understand its structure,
# check for missing values, and visualise key distributions before modelling.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid', palette='muted')
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('../data/sample/demo_transactions.csv', parse_dates=['date'])
print(f'Shape: {df.shape}')
df.head(10)

# %% [markdown]
# ## 2. Data Quality

# %%
print('Data types:\n', df.dtypes)
print('\nMissing values:\n', df.isnull().sum())
print('\nBasic statistics:')
df.describe()

# %% [markdown]
# ## 3. Spending Distribution by Category

# %%
expenses = df[df['type'] == 'expense']

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Total spend per category
cat_totals = expenses.groupby('category')['amount'].sum().sort_values(ascending=False)
cat_totals.plot(kind='bar', ax=axes[0], color='steelblue')
axes[0].set_title('Total Spend per Category')
axes[0].set_ylabel('Amount (₦)')
axes[0].tick_params(axis='x', rotation=45)

# Amount distribution
expenses['amount'].plot(kind='hist', bins=20, ax=axes[1], color='coral')
axes[1].set_title('Distribution of Transaction Amounts')
axes[1].set_xlabel('Amount (₦)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Monthly Income vs Expense Trend

# %%
df['month'] = df['date'].dt.to_period('M')
monthly = df.groupby(['month', 'type'])['amount'].sum().unstack(fill_value=0)

monthly.plot(kind='bar', figsize=(10, 4), color=['salmon', 'mediumseagreen'])
plt.title('Monthly Income vs Expenses')
plt.ylabel('Amount (₦)')
plt.xticks(rotation=45)
plt.legend(['Expense', 'Income'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Observations & Next Steps
#
# - Document any patterns, outliers, or imbalances observed above.
# - Proceed to **Notebook 02** for feature engineering.
